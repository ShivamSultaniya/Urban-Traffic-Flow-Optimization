# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
traffic_data = pd.read_csv("Data/traffic_flow_data.csv")
signal_data = pd.read_csv("Data/signal_timings_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 traffic_data = pd.read_csv("traffic_flow_data.csv")
#       2 signal_data = pd.read_csv("signal_timings_data.csv")
#
# ...

# %%
merged_data = pd.merge(traffic_data, signal_data, on="Intersection")

intersection_signal_analysis = merged_data.groupby("Intersection").agg({
    "Green_Light_Duration": "mean",
    "Red_Light_Duration": "mean",
    "Vehicle_Count": "sum"
}).reset_index()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(intersection_signal_analysis["Green_Light_Duration"], intersection_signal_analysis["Vehicle_Count"], color="green", alpha=0.7)
plt.title("Green Light Duration vs Traffic Volume")
plt.xlabel("Green Light Duration (Seconds)")
plt.ylabel("Total Vehicle Count")
plt.grid(True)
plt.savefig("green_light_vs_traffic.png")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(intersection_signal_analysis["Red_Light_Duration"], intersection_signal_analysis["Vehicle_Count"], color="red", alpha=0.7)
plt.title("Red Light Duration vs Traffic Volume")
plt.xlabel("Red Light Duration (Seconds)")
plt.ylabel("Total Vehicle Count")
plt.grid(True)
plt.savefig("red_light_vs_traffic.png")
plt.show()

# %%
import seaborn as sns

# %%
traffic_data = pd.read_csv("traffic_flow_data.csv")
traffic_data["Time"] = pd.to_datetime(traffic_data["Hour"])
hourly_traffic = traffic_data.groupby("Hour")["Vehicle_Count"].sum().reset_index()

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(x=hourly_traffic["Hour"], y=hourly_traffic["Vehicle_Count"], marker="o", color="blue")
plt.title("Traffic Volume Across Different Hours of the Day")
plt.xlabel("Hour of the Day")
plt.ylabel("Total Vehicle Count")
plt.xticks(range(0, 24))
plt.grid(True)
plt.savefig("traffic_volume_by_hour.png")
plt.show()

# %%
intersection_traffic = traffic_data.groupby("Intersection")["Vehicle_Count"].sum().reset_index()

plt.figure(figsize=(10, 5))
sns.barplot(
    x="Intersection", 
    y="Vehicle_Count", 
    data=intersection_traffic, 
    hue="Intersection",  # Assign x variable to hue
    palette="viridis", 
    legend=False  # Remove the legend
)
plt.title("Traffic Volume Across Different Intersections")
plt.xlabel("Intersection ID")
plt.ylabel("Total Vehicle Count")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.savefig("traffic_volume_by_intersection.png")
plt.show()

# %%
traffic_pivot = traffic_data.pivot_table(
    index="Intersection",
    columns="Hour",
    values="Vehicle_Count",
    aggfunc="sum"
)

plt.figure(figsize=(12, 6))
sns.heatmap(traffic_pivot, cmap="Blues", annot=True, fmt=".0f", linewidths=0.5)
plt.title("Traffic Volume at Each Intersection by Hour")
plt.xlabel("Hour of the Day")
plt.ylabel("Intersection")
plt.xticks(rotation=0)
plt.yticks(rotation=0)
plt.savefig("traffic_heatmap.png")
plt.show()

# %%
total_traffic = traffic_data.groupby("Intersection")["Vehicle_Count"].sum().reset_index()

total_traffic = total_traffic.merge(signal_data, on="Intersection")

total_traffic["Label"] = total_traffic.apply(lambda row: f"{row['Intersection']}({row['Green_Light_Duration']},{row['Red_Light_Duration']})", axis=1)

plt.figure(figsize=(12, 6))
plt.bar(total_traffic["Label"], total_traffic["Vehicle_Count"], color='skyblue')
plt.xlabel("Intersections (Green Light Duration, Red Light Duration)")
plt.ylabel("Total Traffic Volume")
plt.title("Total Traffic Volume at Each Intersection")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig("traffic_volume_by_intersection.png")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(total_traffic["Green_Light_Duration"], total_traffic["Vehicle_Count"], color='green', label='Green Light Duration')
plt.scatter(total_traffic["Red_Light_Duration"], total_traffic["Vehicle_Count"], color='red', label='Red Light Duration')
plt.xlabel("Signal Duration (Seconds)")
plt.ylabel("Total Traffic Volume")
plt.title("Traffic Volume vs. Signal Durations")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.savefig("traffic_volume_by_signal_durations.png")
plt.show()
